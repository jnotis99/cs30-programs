# %% [markdown]
# # CS 30: Modular Exponentiation Algorithm
# ## Joseph Notis, Summer 2020

# %% [markdown]
# ### Implementation of the modular exponentiation algorithm (from lecture 22 notes):

# %%
def mod_exp(a, b, n):
    print("%d^%d mod %d" %(a, b, n))
    preva = a
    a = a % n
    if b == 1: # base case
        return a
    if b % 2 == 0:
        print("= {%d mod %d = %d. %d is even, square %d and divide %d by 2}" % (preva, n, a, b, a, b))
        return mod_exp(a**2, b/2, n) 
    else:
        print("= {%d mod %d = %d. Subtract %d by 1, multiply %d back at the end}" % (preva, n, a, b, a))
        s = mod_exp(a, b-1, n) # s = a^{b-1} mod n
        print ("= {%d ^ %d mod %d = %d. Multiply back the extra %d that was removed}" % (a, b-1, n, s, a))
        return ((a * s) % n)

# %% [markdown]
# ### 3a

# %%
a = 1015378197
n = 2147483647
m = mod_exp(a, 73, n)
print("= %d" % m)
# Out:
# 1015378197^73 mod 2147483647
# = {1015378197 mod 2147483647 = 1015378197. Subtract 73 by 1, multiply 1015378197 back at the end}
# 1015378197^72 mod 2147483647
# = {1015378197 mod 2147483647 = 1015378197. 72 is even, square 1015378197 and divide 72 by 2}
# 1030992882942970809^36 mod 2147483647
# = {1030992882942970809 mod 2147483647 = 644034778. 36 is even, square 644034778 and divide 36 by 2}
# 414780795273509284^18 mod 2147483647
# = {414780795273509284 mod 2147483647 = 359771011. 18 is even, square 359771011 and divide 18 by 2}
# 129435180355962121^9 mod 2147483647
# = {129435180355962121 mod 2147483647 = 1579546177. Subtract 9 by 1, multiply 1579546177 back at the end}
# 1579546177^8 mod 2147483647
# = {1579546177 mod 2147483647 = 1579546177. 8 is even, square 1579546177 and divide 8 by 2}
# 2494966125275315329^4 mod 2147483647
# = {2494966125275315329 mod 2147483647 = 485149043. 4 is even, square 485149043 and divide 4 by 2}
# 235369593923815849^2 mod 2147483647
# = {235369593923815849 mod 2147483647 = 323629173. 2 is even, square 323629173 and divide 2 by 2}
# 104735841616663929^1 mod 2147483647
# = {1579546177 ^ 8 mod 2147483647 = 1840793307. Multiply back the extra 1579546177 that was removed}
# = {1015378197 ^ 72 mod 2147483647 = 1748717054. Multiply back the extra 1015378197 that was removed}
# = 2022242841

# %% [markdown]
# ### 3b

# %%
d = 764857189
print(mod_exp(73 * d, 1, n-1))
# Out:
# 55834574797^1 mod 2147483646
# 1

# %%
print(mod_exp(m, d, 2147483647))
# Out:
# 2022242841^764857189 mod 2147483647
# = {2022242841 mod 2147483647 = 2022242841. Subtract 764857189 by 1, multiply 2022242841 back at the end}
# 2022242841^764857188 mod 2147483647
# = {2022242841 mod 2147483647 = 2022242841. 764857188 is even, square 2022242841 and divide 764857188 by 2}
# 4089466107975751281^382428594 mod 2147483647
# = {4089466107975751281 mod 2147483647 = 275135990. 382428594 is even, square 275135990 and divide 382428594 by 2}
# 75699812993280100^191214297 mod 2147483647
# = {75699812993280100 mod 2147483647 = 824248716. Subtract 191214297 by 1, multiply 824248716 back at the end}
# 824248716^191214296 mod 2147483647
# = {824248716 mod 2147483647 = 824248716. 191214296 is even, square 824248716 and divide 191214296 by 2}
# 679385945827648656^95607148 mod 2147483647
# = {679385945827648656 mod 2147483647 = 558790758. 95607148 is even, square 558790758 and divide 95607148 by 2}
# 312247111226214564^47803574 mod 2147483647
# = {312247111226214564 mod 2147483647 = 1802661587. 47803574 is even, square 1802661587 and divide 47803574 by 2}
# 3249588797245358569^23901787 mod 2147483647
# = {3249588797245358569 mod 2147483647 = 538425728. Subtract 23901787 by 1, multiply 538425728 back at the end}
# 538425728^23901786 mod 2147483647
# = {538425728 mod 2147483647 = 538425728. 23901786 is even, square 538425728 and divide 23901786 by 2}
# 289902264572329984^11950893 mod 2147483647
# = {289902264572329984 mod 2147483647 = 1668686117. Subtract 11950893 by 1, multiply 1668686117 back at the end}
# 1668686117^11950892 mod 2147483647
# = {1668686117 mod 2147483647 = 1668686117. 11950892 is even, square 1668686117 and divide 11950892 by 2}
# 2784513357068537689^5975446 mod 2147483647
# = {2784513357068537689 mod 2147483647 = 2108667811. 5975446 is even, square 2108667811 and divide 5975446 by 2}
# 4446479937147531721^2987723 mod 2147483647
# = {4446479937147531721 mod 2147483647 = 1040094637. Subtract 2987723 by 1, multiply 1040094637 back at the end}
# 1040094637^2987722 mod 2147483647
# = {1040094637 mod 2147483647 = 1040094637. 2987722 is even, square 1040094637 and divide 2987722 by 2}
# 1081796853916161769^1493861 mod 2147483647
# = {1081796853916161769 mod 2147483647 = 1792374764. Subtract 1493861 by 1, multiply 1792374764 back at the end}
# 1792374764^1493860 mod 2147483647
# = {1792374764 mod 2147483647 = 1792374764. 1493860 is even, square 1792374764 and divide 1493860 by 2}
# 3212607294624055696^746930 mod 2147483647
# = {3212607294624055696 mod 2147483647 = 269497393. 746930 is even, square 269497393 and divide 746930 by 2}
# 72628844833796449^373465 mod 2147483647
# = {72628844833796449 mod 2147483647 = 851968122. Subtract 373465 by 1, multiply 851968122 back at the end}
# 851968122^373464 mod 2147483647
# = {851968122 mod 2147483647 = 851968122. 373464 is even, square 851968122 and divide 373464 by 2}
# 725849680904206884^186732 mod 2147483647
# = {725849680904206884 mod 2147483647 = 2059776772. 186732 is even, square 2059776772 and divide 186732 by 2}
# 4242680350470739984^93366 mod 2147483647
# = {4242680350470739984 mod 2147483647 = 1192797866. 93366 is even, square 1192797866 and divide 93366 by 2}
# 1422766749134153956^46683 mod 2147483647
# = {1422766749134153956 mod 2147483647 = 534660744. Subtract 46683 by 1, multiply 534660744 back at the end}
# 534660744^46682 mod 2147483647
# = {534660744 mod 2147483647 = 534660744. 46682 is even, square 534660744 and divide 46682 by 2}
# 285862111174633536^23341 mod 2147483647
# = {285862111174633536 mod 2147483647 = 1597887590. Subtract 23341 by 1, multiply 1597887590 back at the end}
# 1597887590^23340 mod 2147483647
# = {1597887590 mod 2147483647 = 1597887590. 23340 is even, square 1597887590 and divide 23340 by 2}
# 2553244750276008100^11670 mod 2147483647
# = {2553244750276008100 mod 2147483647 = 1672674761. 11670 is even, square 1672674761 and divide 11670 by 2}
# 2797840856086407121^5835 mod 2147483647
# = {2797840856086407121 mod 2147483647 = 717406896. Subtract 5835 by 1, multiply 717406896 back at the end}
# 717406896^5834 mod 2147483647
# = {717406896 mod 2147483647 = 717406896. 5834 is even, square 717406896 and divide 5834 by 2}
# 514672654428354816^2917 mod 2147483647
# = {514672654428354816 mod 2147483647 = 1964519706. Subtract 2917 by 1, multiply 1964519706 back at the end}
# 1964519706^2916 mod 2147483647
# = {1964519706 mod 2147483647 = 1964519706. 2916 is even, square 1964519706 and divide 2916 by 2}
# 3859337675262326436^1458 mod 2147483647
# = {3859337675262326436 mod 2147483647 = 1835611386. 1458 is even, square 1835611386 and divide 1458 by 2}
# 3369469160412840996^729 mod 2147483647
# = {3369469160412840996 mod 2147483647 = 1099958487. Subtract 729 by 1, multiply 1099958487 back at the end}
# 1099958487^728 mod 2147483647
# = {1099958487 mod 2147483647 = 1099958487. 728 is even, square 1099958487 and divide 728 by 2}
# 1209908673123329169^364 mod 2147483647
# = {1209908673123329169 mod 2147483647 = 1103302559. 364 is even, square 1103302559 and divide 364 by 2}
# 1217276536695948481^182 mod 2147483647
# = {1217276536695948481 mod 2147483647 = 754403808. 182 is even, square 754403808 and divide 182 by 2}
# 569125105524900864^91 mod 2147483647
# = {569125105524900864 mod 2147483647 = 861758601. Subtract 91 by 1, multiply 861758601 back at the end}
# 861758601^90 mod 2147483647
# = {861758601 mod 2147483647 = 861758601. 90 is even, square 861758601 and divide 90 by 2}
# 742627886397477201^45 mod 2147483647
# = {742627886397477201 mod 2147483647 = 1570898322. Subtract 45 by 1, multiply 1570898322 back at the end}
# 1570898322^44 mod 2147483647
# = {1570898322 mod 2147483647 = 1570898322. 44 is even, square 1570898322 and divide 44 by 2}
# 2467721538062415684^22 mod 2147483647
# = {2467721538062415684 mod 2147483647 = 1430826648. 22 is even, square 1430826648 and divide 22 by 2}
# 2047264896626915904^11 mod 2147483647
# = {2047264896626915904 mod 2147483647 = 1432726375. Subtract 11 by 1, multiply 1432726375 back at the end}
# 1432726375^10 mod 2147483647
# = {1432726375 mod 2147483647 = 1432726375. 10 is even, square 1432726375 and divide 10 by 2}
# 2052704865620640625^5 mod 2147483647
# = {2052704865620640625 mod 2147483647 = 1359092695. Subtract 5 by 1, multiply 1359092695 back at the end}
# 1359092695^4 mod 2147483647
# = {1359092695 mod 2147483647 = 1359092695. 4 is even, square 1359092695 and divide 4 by 2}
# 1847132953602363025^2 mod 2147483647
# = {1847132953602363025 mod 2147483647 = 866630102. 2 is even, square 866630102 and divide 2 by 2}
# 751047733692530404^1 mod 2147483647
# = {1359092695 ^ 4 mod 2147483647 = 1425244866. Multiply back the extra 1359092695 that was removed}
# = {1432726375 ^ 10 mod 2147483647 = 613729781. Multiply back the extra 1432726375 that was removed}
# = {1570898322 ^ 44 mod 2147483647 = 589768296. Multiply back the extra 1570898322 that was removed}
# = {861758601 ^ 90 mod 2147483647 = 1661026098. Multiply back the extra 861758601 that was removed}
# = {1099958487 ^ 728 mod 2147483647 = 188683675. Multiply back the extra 1099958487 that was removed}
# = {1964519706 ^ 2916 mod 2147483647 = 1922739684. Multiply back the extra 1964519706 that was removed}
# = {717406896 ^ 5834 mod 2147483647 = 691362066. Multiply back the extra 717406896 that was removed}
# = {1597887590 ^ 23340 mod 2147483647 = 1133843746. Multiply back the extra 1597887590 that was removed}
# = {534660744 ^ 46682 mod 2147483647 = 1011474028. Multiply back the extra 534660744 that was removed}
# = {851968122 ^ 373464 mod 2147483647 = 1052395156. Multiply back the extra 851968122 that was removed}
# = {1792374764 ^ 1493860 mod 2147483647 = 155740516. Multiply back the extra 1792374764 that was removed}
# = {1040094637 ^ 2987722 mod 2147483647 = 1471289000. Multiply back the extra 1040094637 that was removed}
# = {1668686117 ^ 11950892 mod 2147483647 = 397566533. Multiply back the extra 1668686117 that was removed}
# = {538425728 ^ 23901786 mod 2147483647 = 2024468367. Multiply back the extra 538425728 that was removed}
# = {824248716 ^ 191214296 mod 2147483647 = 1622161402. Multiply back the extra 824248716 that was removed}
# = {2022242841 ^ 764857188 mod 2147483647 = 1219285194. Multiply back the extra 2022242841 that was removed}
# 1015378197

# %%
print(mod_exp(m, 73 * d, n))
# Out:
# 2022242841^55834574797 mod 2147483647
# = {2022242841 mod 2147483647 = 2022242841. Subtract 55834574797 by 1, multiply 2022242841 back at the end}
# 2022242841^55834574796 mod 2147483647
# = {2022242841 mod 2147483647 = 2022242841. 55834574796 is even, square 2022242841 and divide 55834574796 by 2}
# 4089466107975751281^27917287398 mod 2147483647
# = {4089466107975751281 mod 2147483647 = 275135990. 27917287398 is even, square 275135990 and divide 27917287398 by 2}
# 75699812993280100^13958643699 mod 2147483647
# = {75699812993280100 mod 2147483647 = 824248716. Subtract 13958643699 by 1, multiply 824248716 back at the end}
# 824248716^13958643698 mod 2147483647
# = {824248716 mod 2147483647 = 824248716. 13958643698 is even, square 824248716 and divide 13958643698 by 2}
# 679385945827648656^6979321849 mod 2147483647
# = {679385945827648656 mod 2147483647 = 558790758. Subtract 6979321849 by 1, multiply 558790758 back at the end}
# 558790758^6979321848 mod 2147483647
# = {558790758 mod 2147483647 = 558790758. 6979321848 is even, square 558790758 and divide 6979321848 by 2}
# 312247111226214564^3489660924 mod 2147483647
# = {312247111226214564 mod 2147483647 = 1802661587. 3489660924 is even, square 1802661587 and divide 3489660924 by 2}
# 3249588797245358569^1744830462 mod 2147483647
# = {3249588797245358569 mod 2147483647 = 538425728. 1744830462 is even, square 538425728 and divide 1744830462 by 2}
# 289902264572329984^872415231 mod 2147483647
# = {289902264572329984 mod 2147483647 = 1668686117. Subtract 872415231 by 1, multiply 1668686117 back at the end}
# 1668686117^872415230 mod 2147483647
# = {1668686117 mod 2147483647 = 1668686117. 872415230 is even, square 1668686117 and divide 872415230 by 2}
# 2784513357068537689^436207615 mod 2147483647
# = {2784513357068537689 mod 2147483647 = 2108667811. Subtract 436207615 by 1, multiply 2108667811 back at the end}
# 2108667811^436207614 mod 2147483647
# = {2108667811 mod 2147483647 = 2108667811. 436207614 is even, square 2108667811 and divide 436207614 by 2}
# 4446479937147531721^218103807 mod 2147483647
# = {4446479937147531721 mod 2147483647 = 1040094637. Subtract 218103807 by 1, multiply 1040094637 back at the end}
# 1040094637^218103806 mod 2147483647
# = {1040094637 mod 2147483647 = 1040094637. 218103806 is even, square 1040094637 and divide 218103806 by 2}
# 1081796853916161769^109051903 mod 2147483647
# = {1081796853916161769 mod 2147483647 = 1792374764. Subtract 109051903 by 1, multiply 1792374764 back at the end}
# 1792374764^109051902 mod 2147483647
# = {1792374764 mod 2147483647 = 1792374764. 109051902 is even, square 1792374764 and divide 109051902 by 2}
# 3212607294624055696^54525951 mod 2147483647
# = {3212607294624055696 mod 2147483647 = 269497393. Subtract 54525951 by 1, multiply 269497393 back at the end}
# 269497393^54525950 mod 2147483647
# = {269497393 mod 2147483647 = 269497393. 54525950 is even, square 269497393 and divide 54525950 by 2}
# 72628844833796449^27262975 mod 2147483647
# = {72628844833796449 mod 2147483647 = 851968122. Subtract 27262975 by 1, multiply 851968122 back at the end}
# 851968122^27262974 mod 2147483647
# = {851968122 mod 2147483647 = 851968122. 27262974 is even, square 851968122 and divide 27262974 by 2}
# 725849680904206884^13631487 mod 2147483647
# = {725849680904206884 mod 2147483647 = 2059776772. Subtract 13631487 by 1, multiply 2059776772 back at the end}
# 2059776772^13631486 mod 2147483647
# = {2059776772 mod 2147483647 = 2059776772. 13631486 is even, square 2059776772 and divide 13631486 by 2}
# 4242680350470739984^6815743 mod 2147483647
# = {4242680350470739984 mod 2147483647 = 1192797866. Subtract 6815743 by 1, multiply 1192797866 back at the end}
# 1192797866^6815742 mod 2147483647
# = {1192797866 mod 2147483647 = 1192797866. 6815742 is even, square 1192797866 and divide 6815742 by 2}
# 1422766749134153956^3407871 mod 2147483647
# = {1422766749134153956 mod 2147483647 = 534660744. Subtract 3407871 by 1, multiply 534660744 back at the end}
# 534660744^3407870 mod 2147483647
# = {534660744 mod 2147483647 = 534660744. 3407870 is even, square 534660744 and divide 3407870 by 2}
# 285862111174633536^1703935 mod 2147483647
# = {285862111174633536 mod 2147483647 = 1597887590. Subtract 1703935 by 1, multiply 1597887590 back at the end}
# 1597887590^1703934 mod 2147483647
# = {1597887590 mod 2147483647 = 1597887590. 1703934 is even, square 1597887590 and divide 1703934 by 2}
# 2553244750276008100^851967 mod 2147483647
# = {2553244750276008100 mod 2147483647 = 1672674761. Subtract 851967 by 1, multiply 1672674761 back at the end}
# 1672674761^851966 mod 2147483647
# = {1672674761 mod 2147483647 = 1672674761. 851966 is even, square 1672674761 and divide 851966 by 2}
# 2797840856086407121^425983 mod 2147483647
# = {2797840856086407121 mod 2147483647 = 717406896. Subtract 425983 by 1, multiply 717406896 back at the end}
# 717406896^425982 mod 2147483647
# = {717406896 mod 2147483647 = 717406896. 425982 is even, square 717406896 and divide 425982 by 2}
# 514672654428354816^212991 mod 2147483647
# = {514672654428354816 mod 2147483647 = 1964519706. Subtract 212991 by 1, multiply 1964519706 back at the end}
# 1964519706^212990 mod 2147483647
# = {1964519706 mod 2147483647 = 1964519706. 212990 is even, square 1964519706 and divide 212990 by 2}
# 3859337675262326436^106495 mod 2147483647
# = {3859337675262326436 mod 2147483647 = 1835611386. Subtract 106495 by 1, multiply 1835611386 back at the end}
# 1835611386^106494 mod 2147483647
# = {1835611386 mod 2147483647 = 1835611386. 106494 is even, square 1835611386 and divide 106494 by 2}
# 3369469160412840996^53247 mod 2147483647
# = {3369469160412840996 mod 2147483647 = 1099958487. Subtract 53247 by 1, multiply 1099958487 back at the end}
# 1099958487^53246 mod 2147483647
# = {1099958487 mod 2147483647 = 1099958487. 53246 is even, square 1099958487 and divide 53246 by 2}
# 1209908673123329169^26623 mod 2147483647
# = {1209908673123329169 mod 2147483647 = 1103302559. Subtract 26623 by 1, multiply 1103302559 back at the end}
# 1103302559^26622 mod 2147483647
# = {1103302559 mod 2147483647 = 1103302559. 26622 is even, square 1103302559 and divide 26622 by 2}
# 1217276536695948481^13311 mod 2147483647
# = {1217276536695948481 mod 2147483647 = 754403808. Subtract 13311 by 1, multiply 754403808 back at the end}
# 754403808^13310 mod 2147483647
# = {754403808 mod 2147483647 = 754403808. 13310 is even, square 754403808 and divide 13310 by 2}
# 569125105524900864^6655 mod 2147483647
# = {569125105524900864 mod 2147483647 = 861758601. Subtract 6655 by 1, multiply 861758601 back at the end}
# 861758601^6654 mod 2147483647
# = {861758601 mod 2147483647 = 861758601. 6654 is even, square 861758601 and divide 6654 by 2}
# 742627886397477201^3327 mod 2147483647
# = {742627886397477201 mod 2147483647 = 1570898322. Subtract 3327 by 1, multiply 1570898322 back at the end}
# 1570898322^3326 mod 2147483647
# = {1570898322 mod 2147483647 = 1570898322. 3326 is even, square 1570898322 and divide 3326 by 2}
# 2467721538062415684^1663 mod 2147483647
# = {2467721538062415684 mod 2147483647 = 1430826648. Subtract 1663 by 1, multiply 1430826648 back at the end}
# 1430826648^1662 mod 2147483647
# = {1430826648 mod 2147483647 = 1430826648. 1662 is even, square 1430826648 and divide 1662 by 2}
# 2047264896626915904^831 mod 2147483647
# = {2047264896626915904 mod 2147483647 = 1432726375. Subtract 831 by 1, multiply 1432726375 back at the end}
# 1432726375^830 mod 2147483647
# = {1432726375 mod 2147483647 = 1432726375. 830 is even, square 1432726375 and divide 830 by 2}
# 2052704865620640625^415 mod 2147483647
# = {2052704865620640625 mod 2147483647 = 1359092695. Subtract 415 by 1, multiply 1359092695 back at the end}
# 1359092695^414 mod 2147483647
# = {1359092695 mod 2147483647 = 1359092695. 414 is even, square 1359092695 and divide 414 by 2}
# 1847132953602363025^207 mod 2147483647
# = {1847132953602363025 mod 2147483647 = 866630102. Subtract 207 by 1, multiply 866630102 back at the end}
# 866630102^206 mod 2147483647
# = {866630102 mod 2147483647 = 866630102. 206 is even, square 866630102 and divide 206 by 2}
# 751047733692530404^103 mod 2147483647
# = {751047733692530404 mod 2147483647 = 1425244866. Subtract 103 by 1, multiply 1425244866 back at the end}
# 1425244866^102 mod 2147483647
# = {1425244866 mod 2147483647 = 1425244866. 102 is even, square 1425244866 and divide 102 by 2}
# 2031322928059357956^51 mod 2147483647
# = {2031322928059357956 mod 2147483647 = 125240806. Subtract 51 by 1, multiply 125240806 back at the end}
# 125240806^50 mod 2147483647
# = {125240806 mod 2147483647 = 125240806. 50 is even, square 125240806 and divide 50 by 2}
# 15685259487529636^25 mod 2147483647
# = {15685259487529636 mod 2147483647 = 275135990. Subtract 25 by 1, multiply 275135990 back at the end}
# 275135990^24 mod 2147483647
# = {275135990 mod 2147483647 = 275135990. 24 is even, square 275135990 and divide 24 by 2}
# 75699812993280100^12 mod 2147483647
# = {75699812993280100 mod 2147483647 = 824248716. 12 is even, square 824248716 and divide 12 by 2}
# 679385945827648656^6 mod 2147483647
# = {679385945827648656 mod 2147483647 = 558790758. 6 is even, square 558790758 and divide 6 by 2}
# 312247111226214564^3 mod 2147483647
# = {312247111226214564 mod 2147483647 = 1802661587. Subtract 3 by 1, multiply 1802661587 back at the end}
# 1802661587^2 mod 2147483647
# = {1802661587 mod 2147483647 = 1802661587. 2 is even, square 1802661587 and divide 2 by 2}
# 3249588797245358569^1 mod 2147483647
# = {1802661587 ^ 2 mod 2147483647 = 538425728. Multiply back the extra 1802661587 that was removed}
# = {275135990 ^ 24 mod 2147483647 = 1530096251. Multiply back the extra 275135990 that was removed}
# = {125240806 ^ 50 mod 2147483647 = 209250208. Multiply back the extra 125240806 that was removed}
# = {1425244866 ^ 102 mod 2147483647 = 490762085. Multiply back the extra 1425244866 that was removed}
# = {866630102 ^ 206 mod 2147483647 = 1471063001. Multiply back the extra 866630102 that was removed}
# = {1359092695 ^ 414 mod 2147483647 = 1096172245. Multiply back the extra 1359092695 that was removed}
# = {1432726375 ^ 830 mod 2147483647 = 209863101. Multiply back the extra 1432726375 that was removed}
# = {1430826648 ^ 1662 mod 2147483647 = 1127948602. Multiply back the extra 1430826648 that was removed}
# = {1570898322 ^ 3326 mod 2147483647 = 1657575287. Multiply back the extra 1570898322 that was removed}
# = {861758601 ^ 6654 mod 2147483647 = 31034129. Multiply back the extra 861758601 that was removed}
# = {754403808 ^ 13310 mod 2147483647 = 1621694212. Multiply back the extra 754403808 that was removed}
# = {1103302559 ^ 26622 mod 2147483647 = 1381311869. Multiply back the extra 1103302559 that was removed}
# = {1099958487 ^ 53246 mod 2147483647 = 362303600. Multiply back the extra 1099958487 that was removed}
# = {1835611386 ^ 106494 mod 2147483647 = 528397249. Multiply back the extra 1835611386 that was removed}
# = {1964519706 ^ 212990 mod 2147483647 = 5473925. Multiply back the extra 1964519706 that was removed}
# = {717406896 ^ 425982 mod 2147483647 = 1795131200. Multiply back the extra 717406896 that was removed}
# = {1672674761 ^ 851966 mod 2147483647 = 1449796200. Multiply back the extra 1672674761 that was removed}
# = {1597887590 ^ 1703934 mod 2147483647 = 620017970. Multiply back the extra 1597887590 that was removed}
# = {534660744 ^ 3407870 mod 2147483647 = 759737682. Multiply back the extra 534660744 that was removed}
# = {1192797866 ^ 6815742 mod 2147483647 = 878886026. Multiply back the extra 1192797866 that was removed}
# = {2059776772 ^ 13631486 mod 2147483647 = 1608223473. Multiply back the extra 2059776772 that was removed}
# = {851968122 ^ 27262974 mod 2147483647 = 586874150. Multiply back the extra 851968122 that was removed}
# = {269497393 ^ 54525950 mod 2147483647 = 1798133579. Multiply back the extra 269497393 that was removed}
# = {1792374764 ^ 109051902 mod 2147483647 = 1804348834. Multiply back the extra 1792374764 that was removed}
# = {1040094637 ^ 218103806 mod 2147483647 = 872272169. Multiply back the extra 1040094637 that was removed}
# = {2108667811 ^ 436207614 mod 2147483647 = 1109365721. Multiply back the extra 2108667811 that was removed}
# = {1668686117 ^ 872415230 mod 2147483647 = 1947197078. Multiply back the extra 1668686117 that was removed}
# = {558790758 ^ 6979321848 mod 2147483647 = 1196418181. Multiply back the extra 558790758 that was removed}
# = {824248716 ^ 13958643698 mod 2147483647 = 889697707. Multiply back the extra 824248716 that was removed}
# = {2022242841 ^ 55834574796 mod 2147483647 = 1. Multiply back the extra 2022242841 that was removed}
# 2022242841
